# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import matplotlib.dates as mdates
import re
import sklearn.cluster
from nltk import ngrams
from eppy import modeleditor
from eppy.modeleditor import IDF
IDF.setiddname('C:/EnergyPlusV8-8-0/Energy+.idd')

import warnings
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %matplotlib inline

# %% [markdown]
# # on Tagnames

# %%
raw = pd.read_csv('CSL.csv')
tags = raw.copy()
tags['measure'] = tags['tag'].apply(lambda x: '_'.join(x.split('_')[2:]) )
len(tags['measure'].unique())
# Out:
# 1743

# %%
import itertools  
def razors(string):
    m = len(string)-1
    result = []
    for k in range(min(m+1,7)):
        for bits in itertools.combinations(range(m), k):
            s = [1] * m
            for bit in bits:
                s[bit] = 0
            result.append(s)
    return result

def Xgrams(string):
    substrings = re.split('[ _,:]',string)
    if len(substrings) < 2:
        if len(substrings[0])>8:
            ngrams = [[substrings[0]]]
        else:
            ngrams = []
            for item in razors(string):
                ngram = []
                flag = 0
                for i in range(len(item)):
                    if item[i]:
                        ngram.append(string[flag:i+1])
                        flag = i+1
                ngram.append(string[flag:])
                ngram.sort(key = len,reverse=True)   # so that the longer substrings get matched first
                ngrams.append(ngram)
    else:
        ngrams = [[]]
        for s in substrings:
            if len(s)>3:
                ngrams = list(x+y for x in ngrams for y in [[s]])
            else:
                Ngram = []
                for item in razors(s):
                    ngram = []
                    flag = 0
                    for i in range(len(item)):
                        if item[i]:
                            ngram.append(s[flag:i+1])
                            flag = i+1
                    ngram.append(s[flag:])
                    ngram.sort(key = len,reverse=True)   # so that the longer substrings get matched first
                    Ngram.append(ngram)
                ngrams = list(x+y for x in ngrams for y in Ngram)
    return ngrams

# %%
OPCtag = pd.DataFrame(tags['measure'].unique(),columns=['tag'])

OPCtag['Xgrams'] = OPCtag['tag'].apply(lambda x: str.upper(' '.join(x.split('_'))))

OPCtag['Xgrams'] = OPCtag['Xgrams'].apply(lambda x: Xgrams(x))
OPCtag[:50]
# Out:
#                                                   tag  \
# 0               Floor_1760001_Master_Hyperion_Enabled
# 1    Floor_1760001_Master_Hyperion_Mode_Sunny_or_Dark
# 2               Floor_1760001_Master_Loadshed_Enabled
# 3      Floor_1760001_Timeclock_atrium_evening_Enabled
# 4   Floor_1760001_Timeclock_Disable_Wall_Control_E...
# 5       Floor_1760001_Timeclock_Dusk_to_11_PM_Enabled
# 6        Floor_1760001_Timeclock_Dusk_to_Dawn_Enabled
# 7   Floor_1760001_Timeclock_Interior_Atrium_Lighti...
# 8   Floor_1760001_Timeclock_Interior_Lighting_Non_...
# 9                                        ALT OAT FAIL
# 10                                     Alt OAT Sensor
# 11                                     OA Dewpoint AV
# 12                                     OA Enthalpy AV
# 13                                     OA Humidity AV
# 14                                  OA Temperature AV
# 15                                           OAH FAIL
# 16                                         OAH Sensor
# 17                            Outside Air Temperature
# 18                                      PRIM OAT FAIL
# 19                                Conversion Constant
# 20                                    Daily Use Write
# 21                                  Energy Peak Synch
# 22                        Energy Peak Synchronization
# 23                                   Energy Use Synch
# 24                         Energy Use Synchronization
# 25                                               Flow
# 26                                     Instant Demand
# 27                                            IN_FAIL
# 28                                  Monthly Use Write
# 29                                           Peak MTD
# 30                                         Peak Today
# 31                                           Peak YTD
# 32                                     PreCoil Enable
# 33                                 Prev Day Peak Dmnd
# 34                                     Prev Day Usage
# 35                                    Prev Month Peak
# 36                                   Prev Month Usage
# 37                                     Prev Year Peak
# 38                                    Prev Year Usage
# 39                                        Return Temp
# 40                                        Supply Temp
# 41                                          Usage MTD
# 42                                        Usage Today
# 43                                          Usage YTD
# 44                                   Use Every Minute
# 45                                   Yearly Use Write
# 46                                      Reheat Enable
# 47                 1st Flr Atrium Natural Ventilation
# 48                      2/3 Duct Static Pressure STPT
# 49                 2nd Flr Atrium Natural Ventilation
#
#                                                Xgrams
# 0       [[FLOOR, 1760001, MASTER, HYPERION, ENABLED]]
# 1   [[FLOOR, 1760001, MASTER, HYPERION, MODE, SUNN...
# 2       [[FLOOR, 1760001, MASTER, LOADSHED, ENABLED]]
# 3   [[FLOOR, 1760001, TIMECLOCK, ATRIUM, EVENING, ...
# 4   [[FLOOR, 1760001, TIMECLOCK, DISABLE, WALL, CO...
# 5   [[FLOOR, 1760001, TIMECLOCK, DUSK, T, O, 1, 1,...
# 6   [[FLOOR, 1760001, TIMECLOCK, DUSK, T, O, DAWN,...
# 7   [[FLOOR, 1760001, TIMECLOCK, INTERIOR, ATRIUM,...
# 8   [[FLOOR, 1760001, TIMECLOCK, INTERIOR, LIGHTIN...
# 9   [[A, L, T, O, A, T, FAIL], [A, L, T, OA, T, FA...
# 10  [[A, L, T, O, A, T, SENSOR], [A, L, T, OA, T, ...
# 11  [[O, A, DEWPOINT, A, V], [O, A, DEWPOINT, AV],...
# 12  [[O, A, ENTHALPY, A, V], [O, A, ENTHALPY, AV],...
# 13  [[O, A, HUMIDITY, A, V], [O, A, HUMIDITY, AV],...
# 14  [[O, A, TEMPERATURE, A, V], [O, A, TEMPERATURE...
# 15  [[O, A, H, FAIL], [OA, H, FAIL], [AH, O, FAIL]...
# 16  [[O, A, H, SENSOR], [OA, H, SENSOR], [AH, O, S...
# 17  [[OUTSIDE, A, I, R, TEMPERATURE], [OUTSIDE, AI...
# 18  [[PRIM, O, A, T, FAIL], [PRIM, OA, T, FAIL], [...
# 19                           [[CONVERSION, CONSTANT]]
# 20  [[DAILY, U, S, E, WRITE], [DAILY, US, E, WRITE...
# 21                            [[ENERGY, PEAK, SYNCH]]
# 22                  [[ENERGY, PEAK, SYNCHRONIZATION]]
# 23  [[ENERGY, U, S, E, SYNCH], [ENERGY, US, E, SYN...
# 24  [[ENERGY, U, S, E, SYNCHRONIZATION], [ENERGY, ...
# 25  [[F, L, O, W], [FL, O, W], [LO, F, W], [OW, F,...
# 26                                [[INSTANT, DEMAND]]
# 27                         [[I, N, FAIL], [IN, FAIL]]
# 28  [[MONTHLY, U, S, E, WRITE], [MONTHLY, US, E, W...
# 29  [[PEAK, M, T, D], [PEAK, MT, D], [PEAK, TD, M]...
# 30                                    [[PEAK, TODAY]]
# 31  [[PEAK, Y, T, D], [PEAK, YT, D], [PEAK, TD, Y]...
# 32                                [[PRECOIL, ENABLE]]
# 33  [[PREV, D, A, Y, PEAK, DMND], [PREV, DA, Y, PE...
# 34  [[PREV, D, A, Y, USAGE], [PREV, DA, Y, USAGE],...
# 35                              [[PREV, MONTH, PEAK]]
# 36                             [[PREV, MONTH, USAGE]]
# 37                               [[PREV, YEAR, PEAK]]
# 38                              [[PREV, YEAR, USAGE]]
# 39                                   [[RETURN, TEMP]]
# 40                                   [[SUPPLY, TEMP]]
# 41  [[USAGE, M, T, D], [USAGE, MT, D], [USAGE, TD,...
# 42                                   [[USAGE, TODAY]]
# 43  [[USAGE, Y, T, D], [USAGE, YT, D], [USAGE, TD,...
# 44  [[U, S, E, EVERY, MINUTE], [US, E, EVERY, MINU...
# 45  [[YEARLY, U, S, E, WRITE], [YEARLY, US, E, WRI...
# 46                                 [[REHEAT, ENABLE]]
# 47  [[1, S, T, F, L, R, ATRIUM, NATURAL, VENTILATI...
# 48  [[2, /, 3, DUCT, STATIC, PRESSURE, STPT], [2/,...
# 49  [[2, N, D, F, L, R, ATRIUM, NATURAL, VENTILATI...

# %%
OPCtag[OPCtag['tag'].str.contains('Supply')]
# Out:
#                           tag  \
# 40                Supply Temp
# 213            Supply Air CFM
# 214  Supply Air Temp Setpoint
# 215           Supply Air Temp
# 216       Supply Airflow kCFM
# 217            Supply Fan S/S
#
#                                                   gram
# 40                                    [[SUPPLY, TEMP]]
# 213  [[SUPPLY, A, I, R, C, F, M], [SUPPLY, A, I, R,...
# 214  [[SUPPLY, A, I, R, TEMP, SETPOINT], [SUPPLY, A...
# 215  [[SUPPLY, A, I, R, TEMP], [SUPPLY, AI, R, TEMP...
# 216                          [[SUPPLY, AIRFLOW, KCFM]]
# 217  [[SUPPLY, F, A, N, S, /, S], [SUPPLY, F, A, N,...

# %%
OPCtag[OPCtag['tag']=='OA Dewpoint AV']
# Out:
#                tag                                             Xgrams
# 11  OA Dewpoint AV  [[O, A, DEWPOINT, A, V], [O, A, DEWPOINT, AV],...

# %% [markdown]
# # create dict

# %%
def updateABB(abb,full):
    global ABBdict
    for i in full:
        if i in list(ABBdict['name']):
            ABBdict['abb'].loc[ABBdict['name']==i].item().add(abb[full.index(i)])
        else:
            ABBdict = ABBdict.append({'abb': set([abb[full.index(i)]]),'name':i}, ignore_index=True)

# %%
dict1 = pd.read_csv('HVACacronym.csv')
dict2 = pd.read_csv('HVACacronym1.csv')

dict1['full']=dict1['full'].apply(lambda x: str.lower(x))
dict2['name']=dict2['name'].apply(lambda x: str.lower(x))

ABBdict = pd.concat([dict1.rename({'full':'name'}, axis='columns'),dict2])
ABBdict['abb']= ABBdict[['abb']].values.tolist()
ABBdict = pd.DataFrame(ABBdict.groupby('name')['abb'].sum())
ABBdict['name']=ABBdict.index
ABBdict.rename(index=str, columns={0: "abb"},inplace=True)
ABBdict['abb']= ABBdict['abb'].apply(lambda x: set(x))

ABBdict.reset_index(drop=True,inplace=True)

# %%
abb = ['OC','TMP','TEMP','SA','STATIC','RA','RH','RM','BM','FLWR','RET','KWATT','KWHR','PM','ENGRY','FWD','PWR','AHU',
      'FAN','SPEED','BYP','CLG','WATER','VLV','TP','SMK','FA','PM','BM','CURR','VOLT','PW']
full=['off coil','temperature','temperature','supply air','pressure','return air','relative humidity','room',
      'btu meter','flow rate','return','power','energy','power meter','energy','supply','power','ahu',
      'fan','speed','bypass','cooling','water','valve','time program','smoke','fresh air','power meter','btu meter',
      'current','voltage','power']
updateABB(abb,full)

EPname = ['zone','air','coil','energy','heating','cooling','air terminal','pump','boiler','condenser','setpoint',
          'heat exchanger','humidifier','heater','water','people','window','infiltration','equipment','outdoor',
          'drybulb','dewpoint','speed','angle','radiation','pressure','precipitation','occupant','lights',
          'humidity ratio','facility','mass flow rate','interior','gas','office','room','level','extract',
          'fan','supply','air loop','site','power','radiant','fan coil unit','indoor','heat pump',
          'vav','vrf','return','inlet','outlet','relief air','rate']

EPabb = ['RM','A','C','KWHR','HT','CL','VAV','PMP','B','COND','SP','HX','HUMID','HTR','WTR','PPL','WD','INFIL',
        'EQUIP','O','DB','DP','SPD','AGL','R','PR','P','OCC','LT','HR','FAC','FLWR','INTR','G','OFC','RM','LV',
        'E','F','S','AHU','LOC','KWATT','R','FCU','I','CU','VAV','VRF','R','S','R','EA','KW']
updateABB(EPabb,EPname)

NODEname = ['supply side inlet','supply side outlet','coil air outlet','mixed inlet','splitter outlet',
           'coil outlet','inlet','outlet','supply inlet']

NODEabb = ['R','S','OC','R','S','S','FWD','RET','R']

updateABB(NODEabb,NODEname)

testName = ['electricity','energy','power','demand','rate','coil air outlet','coil outlet']

testABB = ['KWHR','ENGRY','PWR','ENGRY','PWR','S','OC']

updateABB(testABB,testName)

# %%
iwName = ['dewpoint','relative humidity','humidity ratio','wind','direction','global','solar',
          'zone','electricity','water','mass flow rate']
iwABB = ['DWP','HM','HM','W','DIREC','GLO','S','R','TOTKW','W','FL']
updateABB(iwABB,iwName)

iwName = ['humidity ratio','relative humidity','mass flow rate']
iwABB = ['HUM','HUM','FLO']
updateABB(iwABB,iwName)

sdeName = ['temperature','dewpoint','relative humidity','humidity ratio','pressure','barometric','wind','direction',
          'solar','radiation','precipitation','electricity','energy','purchased','net','produced']
sdeABB = ['TEMPERATURE','DEW','HUMIDITY','HUMIDITY','PRESSURE','BAROMETRIC','WIND','DIRECTION','SOLAR',
         'RADIATION','PRECIPITATION','POWER','ENERGY','RECEIVED','BALANCE','DELIVERED']
updateABB(sdeABB,sdeName)

sdeABB = ['KWH','SP']
sdeName = ['electricity','pressure']
updateABB(sdeABB,sdeName)

# %%
CSLabb = ['DEWPOINT','H','H','OCCUPANCY','USAGE','SUPPLY','CFM','STPT','ZN']
CSLname = ['dewpoint','humidity ratio','relative humidity','occupant','energy','inlet','flow rate','setpoint','zone']
updateABB(CSLabb,CSLname)

CSLabb = ['KCFM','SETPOINT','RETURN','RETURN','ZONE','SUPPLY','RETURN']
CSLname = ['flow rate','setpoint','supply inlet','outlet','zone','supply side outlet','return']
updateABB(CSLabb,CSLname)

CSL3abb = ['FLOW','RETURN']
CSL3name = ['flow rate','supply side inlet']
updateABB(CSL3abb,CSL3name)

ABBdict[ABBdict['name'].str.contains('flow rate')]
# Out:
#                          abb            name
# 287  {KCFM, CFM, FLOW, FLWR}       flow rate
# 324          {FLO, FLWR, FL}  mass flow rate

# %% [markdown]
# # map

# %%
def match(s,OPCtag,th):
    
    ngram = []
    for i in range(3,0,-1):
        grams = ngrams(s.split(' '),i)
        for gram in grams:
            ngram.append(' '.join(list(gram)))
    
#     ngram.sort(key = lambda s: len(s),reverse = True)
    ABBs = []
    while len(ngram)>0:
        i = ngram[0]
        ngram.remove(i)
#         print(ngram)
        try:
            ABBs.append(ABBdict.loc[ABBdict['name'] == i,'abb'].values[0])
            ngram = [s for s in ngram if (s not in i)]
        except:
            pass

    details = []
    for i in OPCtag.index:
        idx = 0
        m = 0
        r = 0
        for j in range(len(OPCtag['Xgrams'][i])):
            used = [0]*len(ABBs)    # so that a set of ABBs is only matched once
            count = 0
            for gram in OPCtag.loc[i,'Xgrams'][j]:
                for c in range(len(ABBs)):
                    if gram in ABBs[c] and used[c]==0:
                        used[c] = 1
                        count += len(gram)
                        break
            if count > m:
                m = count # to avoid division by zero error
                # harmonic average of ratio on both side
                r = 2/(len(ABBs)/sum(used) + len(OPCtag['tag'][i])/m)
                idx = j
# criteria passed: # of hits, # of total hit characters in tag, ratio of hit sets over total
        if r >= .01:
            details.append([round(r,4),OPCtag['tag'][i],tuple(OPCtag['Xgrams'][i][idx])])

    details = list(set(tuple(x) for x in details))
    details.sort()
    matches = [i[1] for i in details][-th:] #top 10 vs top 7 (10%) tested

    return [matches,details,ABBs]

# %%
def check(result):
    for i in result.index:
        if len(result.loc[i,'matches']) == 0:
            if np.nan in result.loc[i,'truth']:
                result.loc[i,'test'] = 'TN'
            else:
                result.loc[i,'test'] = 'FN'
        elif np.nan in result.loc[i,'truth']:
            result.loc[i,'test'] = 'FP'
        else:
            for m in result.loc[i,'truth']:
                if m in result.loc[i,'matches']:
                    result.loc[i,'test'] = 'TP'
                    break
                else:
                    result.loc[i,'test'] = 'FP1'
    return result

# %% [markdown]
# # reading E+ outputs

# %%
truth = pd.read_csv('truthCSL.csv')
for i in truth.index:
    if truth.loc[i,'alter'] in [np.nan]:
        truth.loc[i,'truth'] = [truth.loc[i,'truth']]
    else:
        truth.loc[i,'truth'] = [truth.loc[i,'truth'],truth.loc[i,'alter']]
truth.drop(columns=['alter'],inplace = True)
truth[truth['truth'].str.len()>1]
# Out:
#                                     input  \
# 0    site outdoor air drybulb temperature
# 2         site outdoor air humidity ratio
# 3      site outdoor air relative humidity
# 5                         site wind speed
# 27           zone mean air humidity ratio
# 31                        energy transfer
# 55          energy transfer cooling coils
# 92     demand side inlet 1 mass flow rate
# 98    supply side outlet 1 mass flow rate
# 146     supply side outlet mass flow rate
# 285          zone air node humidity ratio
# 286    zone air node setpoint temperature
#
#                                      truth
# 0                           [OA Temp, OAT]
# 2                    [OA Humidity AV, OAH]
# 3                    [OA Humidity AV, OAH]
# 5                    [WIND SPEED, WindSpd]
# 27                        [ZNH HI, ZNH LO]
# 31                  [Usage MTD, Usage YTD]
# 55                  [Usage MTD, Usage YTD]
# 92   [Supply Airflow kCFM, Supply Air CFM]
# 98   [Supply Airflow kCFM, Supply Air CFM]
# 146  [Supply Airflow kCFM, Supply Air CFM]
# 285                       [ZNH HI, ZNH LO]
# 286             [zone_setpoint, Zone Stpt]

# %%
top5 = pd.DataFrame(columns = ['input','abbs','matches'])
ls = truth['input'].unique()
# add some input variables to map
for i in range(len(ls)):
    test = match(ls[i],OPCtag,5)
#     print(i,end=' ')
#     print(test[1])
    top5.loc[i,'input'] = ls[i]
    top5.loc[i,'abbs'] = test[2]
    top5.loc[i,'matches'] = test[0]
#     result.loc[i,'detail'] = test[1]
top5 = top5.join(truth.set_index('input'), on='input')

# %%
t5 = check(top5)
t5['test'].value_counts()
# Out:
# FP     414
# TP      47
# FP1      4
# TN       1
# Name: test, dtype: int64

# %%
t5[t5['test']=='FP1']
# Out:
#                                      input  \
# 1    site outdoor air dewpoint temperature
# 27            zone mean air humidity ratio
# 285           zone air node humidity ratio
# 451       air relief node name temperature
#
#                                                   abbs  \
# 1    [{LOC}, {O}, {A}, {DEWPOINT, DP, DWP, DEW}, {T...
# 27   [{H, HUMIDITY, HUM, HM, HR}, {RM, R, ZN, ZONE}...
# 285  [{H, HUMIDITY, HUM, HM, HR}, {RM, R, ZN, ZONE}...
# 451          [{A}, {RLF}, {T, TEMP, TMP, TEMPERATURE}]
#
#                                                matches              truth test
# 1     [OA Temp, oa_dewpoint, oa_temperature, OAT, oat]   [OA Dewpoint AV]  FP1
# 27   [hoa, oah, OA Humidity, oa_humidity, RA Humidity]   [ZNH HI, ZNH LO]  FP1
# 285  [hoa, oah, OA Humidity, oa_humidity, RA Humidity]   [ZNH HI, ZNH LO]  FP1
# 451  [OAT, oat, OA Temperature AV, OA Temp, oa_temp...  [Return Air Temp]  FP1

# %%
def check1(result):
    for i in result.index:
        if len(result.loc[i,'matches']) == 0:
            if np.nan in result.loc[i,'truth']:
                result.loc[i,'test'] = 'TN'
            else:
                result.loc[i,'test'] = 'FN'
        elif np.nan in result.loc[i,'truth']:
            result.loc[i,'test'] = 'FP'
        else:
            for m in result.loc[i,'truth']:
                if m == result.loc[i,'matches'][-1]:
                    result.loc[i,'test'] = 'TP'
                    break
                else:
                    result.loc[i,'test'] = 'FP1'
    return result

# %%
t7 = check1(top5)
t7['test'].value_counts()
# Out:
# FP     414
# TP      27
# FP1     24
# TN       1
# Name: test, dtype: int64

# %% [markdown]
# # baseline

# %%
def onNgram(s,OPCtag,th):
    
    ngram = []
    for i in range(3,0,-1):
        grams = ngrams(s.split(' '),i)
        for gram in grams:
            ngram.append(' '.join(list(gram)))
    
#     ngram.sort(key = lambda s: len(s),reverse = True)
    ABBs = []
    while len(ngram)>0:
        i = ngram[0]
        ngram.remove(i)
        try:
            ABBs.append(ABBdict.loc[ABBdict['name'] == i,'abb'].values[0])
            ngram = [s for s in ngram if (s not in i)]
        except:
            pass
    
    detail = []
    for i in OPCtag.index:
        r = 0
        used = [0]*len(ABBs)    # so that a set of ABBs is only matched once
        count = 0
        for gram in OPCtag['ngram'][i]:
            for c in range(len(ABBs)):
                if gram in ABBs[c] and used[c]==0:
                    used[c] = 1
                    count += 1
                    break
# criteria passed: # of hits, # of total hit characters in tag, ratio of hit sets over total
        if count >= 1:
            # harmonic average of ratio on both side
#             r = 2/(len(ABBs)/sum(used) + len(OPCtag['ngram'][i])/count)
#             Jaccard similarity
            r = count/(len(ABBs)+len(OPCtag['ngram'][i])-count)
            detail.append([round(r,4),OPCtag['tag'][i]])  #,tuple(OPCtag['ngram'][i])

    detail = list(set(tuple(x) for x in detail))
    detail.sort()
    matches = [i[1] for i in detail][-th:] #top 10 vs top 7 (10%) tested
            
    return [matches,detail,ABBs]

# test = match(str.lower('Zone Mean Air Temperature'),OPCtag)
# set(tuple(x) for x in test[0])

# %%
OPCtag['ngram'] = OPCtag['tag'].apply(lambda x: str.upper(x))
for i in OPCtag.index:
    Ngrams = []    
    substrings = re.split('[ _,:]',OPCtag['ngram'][i])
    if len(substrings) < 2:
        if len(substrings[0])>8:
            Ngrams = [substrings[0]]
        else:
            for n in range(1,min(7,len(substrings[0])+1)):
                grams = ngrams(substrings[0],n)
                for gram in grams:
                    Ngrams.append(''.join(list(gram)))
    else:
        for s in substrings:
            if len(s)>3:
                Ngrams.append(s)
            else:
                for n in range(1,min(7,len(s)+1)):
                    grams = ngrams(s,n)
                    for gram in grams:
                        Ngrams.append(''.join(list(gram)))

    OPCtag.at[i,'ngram'] = Ngrams
OPCtag[:30]
# Out:
#                                                   tag  \
# 0               Floor_1760001_Master_Hyperion_Enabled
# 1    Floor_1760001_Master_Hyperion_Mode_Sunny_or_Dark
# 2               Floor_1760001_Master_Loadshed_Enabled
# 3      Floor_1760001_Timeclock_atrium_evening_Enabled
# 4   Floor_1760001_Timeclock_Disable_Wall_Control_E...
# 5       Floor_1760001_Timeclock_Dusk_to_11_PM_Enabled
# 6        Floor_1760001_Timeclock_Dusk_to_Dawn_Enabled
# 7   Floor_1760001_Timeclock_Interior_Atrium_Lighti...
# 8   Floor_1760001_Timeclock_Interior_Lighting_Non_...
# 9                                        ALT OAT FAIL
# 10                                     Alt OAT Sensor
# 11                                     OA Dewpoint AV
# 12                                     OA Enthalpy AV
# 13                                     OA Humidity AV
# 14                                  OA Temperature AV
# 15                                           OAH FAIL
# 16                                         OAH Sensor
# 17                            Outside Air Temperature
# 18                                      PRIM OAT FAIL
# 19                                Conversion Constant
# 20                                    Daily Use Write
# 21                                  Energy Peak Synch
# 22                        Energy Peak Synchronization
# 23                                   Energy Use Synch
# 24                         Energy Use Synchronization
# 25                                               Flow
# 26                                     Instant Demand
# 27                                            IN_FAIL
# 28                                  Monthly Use Write
# 29                                           Peak MTD
#
#                                                Xgrams  \
# 0       [[FLOOR, 1760001, MASTER, HYPERION, ENABLED]]
# 1   [[FLOOR, 1760001, MASTER, HYPERION, MODE, SUNN...
# 2       [[FLOOR, 1760001, MASTER, LOADSHED, ENABLED]]
# 3   [[FLOOR, 1760001, TIMECLOCK, ATRIUM, EVENING, ...
# 4   [[FLOOR, 1760001, TIMECLOCK, DISABLE, WALL, CO...
# 5   [[FLOOR, 1760001, TIMECLOCK, DUSK, T, O, 1, 1,...
# 6   [[FLOOR, 1760001, TIMECLOCK, DUSK, T, O, DAWN,...
# 7   [[FLOOR, 1760001, TIMECLOCK, INTERIOR, ATRIUM,...
# 8   [[FLOOR, 1760001, TIMECLOCK, INTERIOR, LIGHTIN...
# 9   [[A, L, T, O, A, T, FAIL], [A, L, T, OA, T, FA...
# 10  [[A, L, T, O, A, T, SENSOR], [A, L, T, OA, T, ...
# 11  [[O, A, DEWPOINT, A, V], [O, A, DEWPOINT, AV],...
# 12  [[O, A, ENTHALPY, A, V], [O, A, ENTHALPY, AV],...
# 13  [[O, A, HUMIDITY, A, V], [O, A, HUMIDITY, AV],...
# 14  [[O, A, TEMPERATURE, A, V], [O, A, TEMPERATURE...
# 15  [[O, A, H, FAIL], [OA, H, FAIL], [AH, O, FAIL]...
# 16  [[O, A, H, SENSOR], [OA, H, SENSOR], [AH, O, S...
# 17  [[OUTSIDE, A, I, R, TEMPERATURE], [OUTSIDE, AI...
# 18  [[PRIM, O, A, T, FAIL], [PRIM, OA, T, FAIL], [...
# 19                           [[CONVERSION, CONSTANT]]
# 20  [[DAILY, U, S, E, WRITE], [DAILY, US, E, WRITE...
# 21                            [[ENERGY, PEAK, SYNCH]]
# 22                  [[ENERGY, PEAK, SYNCHRONIZATION]]
# 23  [[ENERGY, U, S, E, SYNCH], [ENERGY, US, E, SYN...
# 24  [[ENERGY, U, S, E, SYNCHRONIZATION], [ENERGY, ...
# 25  [[F, L, O, W], [FL, O, W], [LO, F, W], [OW, F,...
# 26                                [[INSTANT, DEMAND]]
# 27                         [[I, N, FAIL], [IN, FAIL]]
# 28  [[MONTHLY, U, S, E, WRITE], [MONTHLY, US, E, W...
# 29  [[PEAK, M, T, D], [PEAK, MT, D], [PEAK, TD, M]...
#
#                                                 ngram
# 0         [FLOOR, 1760001, MASTER, HYPERION, ENABLED]
# 1   [FLOOR, 1760001, MASTER, HYPERION, MODE, SUNNY...
# 2         [FLOOR, 1760001, MASTER, LOADSHED, ENABLED]
# 3   [FLOOR, 1760001, TIMECLOCK, ATRIUM, EVENING, E...
# 4   [FLOOR, 1760001, TIMECLOCK, DISABLE, WALL, CON...
# 5   [FLOOR, 1760001, TIMECLOCK, DUSK, T, O, TO, 1,...
# 6   [FLOOR, 1760001, TIMECLOCK, DUSK, T, O, TO, DA...
# 7   [FLOOR, 1760001, TIMECLOCK, INTERIOR, ATRIUM, ...
# 8   [FLOOR, 1760001, TIMECLOCK, INTERIOR, LIGHTING...
# 9   [A, L, T, AL, LT, ALT, O, A, T, OA, AT, OAT, F...
# 10  [A, L, T, AL, LT, ALT, O, A, T, OA, AT, OAT, S...
# 11                     [O, A, OA, DEWPOINT, A, V, AV]
# 12                     [O, A, OA, ENTHALPY, A, V, AV]
# 13                     [O, A, OA, HUMIDITY, A, V, AV]
# 14                  [O, A, OA, TEMPERATURE, A, V, AV]
# 15                       [O, A, H, OA, AH, OAH, FAIL]
# 16                     [O, A, H, OA, AH, OAH, SENSOR]
# 17       [OUTSIDE, A, I, R, AI, IR, AIR, TEMPERATURE]
# 18                 [PRIM, O, A, T, OA, AT, OAT, FAIL]
# 19                             [CONVERSION, CONSTANT]
# 20               [DAILY, U, S, E, US, SE, USE, WRITE]
# 21                              [ENERGY, PEAK, SYNCH]
# 22                    [ENERGY, PEAK, SYNCHRONIZATION]
# 23              [ENERGY, U, S, E, US, SE, USE, SYNCH]
# 24    [ENERGY, U, S, E, US, SE, USE, SYNCHRONIZATION]
# 25           [F, L, O, W, FL, LO, OW, FLO, LOW, FLOW]
# 26                                  [INSTANT, DEMAND]
# 27                                   [I, N, IN, FAIL]
# 28             [MONTHLY, U, S, E, US, SE, USE, WRITE]
# 29                       [PEAK, M, T, D, MT, TD, MTD]

# %%
top7 = pd.DataFrame(columns = ['input','abbs','matches'])
ls = truth['input'].unique()
# add some input variables to map
for i in range(len(ls)):
    test = onNgram(ls[i],OPCtag,5)
#     print(i,end=' ')
#     print(test[1])
    top7.loc[i,'input'] = ls[i]
    top7.loc[i,'abbs'] = test[2]
    top7.loc[i,'matches'] = test[0]
#     result.loc[i,'detail'] = test[1]
top7 = top7.join(truth.set_index('input'), on='input')

# %%
t7 = check(top7)
t7['test'].value_counts()
# Out:
# FP     414
# TP      32
# FP1     19
# TN       1
# Name: test, dtype: int64

# %%
t7 = check1(top7)
t7['test'].value_counts()
# Out:
# FP     414
# FP1     33
# TP      18
# TN       1
# Name: test, dtype: int64

# %%
top7[top7['test']=='FP1']
# Out:
#                              input  \
# 149  supply side inlet temperature
# 167    air outlet node temperature
# 203  water outlet node temperature
# 431             outlet temperature
#
#                                                abbs  \
# 149  [{FWD, S, SUP}, {FWD, S}, {T, TEMP, TMP}, {R}]
# 167                      [{A}, {R}, {T, TEMP, TMP}]
# 203             [{WATER, WTR}, {R}, {T, TEMP, TMP}]
# 431                           [{R}, {T, TEMP, TMP}]
#
#                                                matches       truth test
# 149  [RMTEMP, SATEMP, SS, RMTEMPSPB, RATEMPSP, RMTE...    [RATEMP]  FP1
# 167  [RMTEMPSP, ATEMPSP, RATEMPLOALM, RMTEMP, SATEM...    [OCTEMP]  FP1
# 203  [TRIP, WATERDETALM, RMTEMPSPB, RATEMPSP, RMTEM...  [BMRETTMP]  FP1
# 431  [TMP, TRIP, RMTEMPSPB, RATEMPSP, RMTEMPSP, RAT...    [OCTEMP]  FP1

# %%
top7[top7['test']=='FP1']
# Out:
#                                        input  \
# 110        supply inlet setpoint temperature
# 146  supply side outlet setpoint temperature
# 147     supply side outlet relative humidity
# 153      supply side inlet relative humidity
# 167              air outlet node temperature
# 431                       outlet temperature
#
#                                                 abbs  \
# 110  [{SUP, FWD, S}, {FWD, S}, {SP}, {TMP, TEMP, T}]
# 146                      [{S}, {SP}, {TMP, TEMP, T}]
# 147                                      [{S}, {RH}]
# 153                                      [{R}, {RH}]
# 167                  [{A}, {R, RET}, {TMP, TEMP, T}]
# 431                       [{R, RET}, {TMP, TEMP, T}]
#
#                                                matches       truth test
# 110  [RMTEMPSP, SATEMP, ATEMPSP, SASTATICSP, SS, TM...  [SATEMPSP]  FP1
# 146  [RMTEMPSPB, STS, RATEMPSP, RMTEMPSP, SATEMP, A...  [SATEMPSP]  FP1
# 147           [SMKDET, TMPSP, AFS, STS, VSD, RARH, SS]  [RATEMPSP]  FP1
# 153   [RATEMP, RMTEMP, BMPWR, RACO2, DMPR, TRIP, RARH]  [RATEMPSP]  FP1
# 167  [ATEMPSP, BMRETTMP, RATEMPLOALM, RMTEMP, SATEM...    [OCTEMP]  FP1
# 431  [TRIP, RMTEMPSPB, RATEMPSP, RMTEMPSP, BMRETTMP...    [OCTEMP]  FP1

# %%
t7.to_csv('TOcheck.csv')
